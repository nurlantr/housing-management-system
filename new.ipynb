# %%
import pandas as pd
from models import Dormitory
from populator import Populator
nu = Dormitory()
populator = Populator('', nu)

# %%
df = populator.read_excel_dorm('new_may_input.xlsx')
# Out:
# Successfully added student 201993360.0 into room 23.301
# Successfully added student 201866470.0 into room 23.303
# Successfully added student 201896991.0 into room 23.303
# Successfully added student 201725669.0 into room 23.304
# Successfully added student 201687793.0 into room 23.306
# Successfully added student 201827969.0 into room 23.306
# Successfully added student 201869284.0 into room 23.307
# Successfully added student 202028149.0 into room 23.309
# Successfully added student 202194245.0 into room 23.310
# Successfully added student 201977637.0 into room 23.312
# Successfully added student 201998650.0 into room 23.312
# Successfully added student 201581432.0 into room 23.313
# Successfully added student 201716900.0 into room 23.313
# Successfully added student 201756407.0 into room 23.314
# Successfully added student 201794075.0 into room 23.314
# Successfully added student 202073698.0 into room 23.315
# Successfully added student 202099067.0 into room 23.315
# ...

# %%
print(len(nu.get_rooms(23,27,1)))
# Out:
# 496

# %%
pd.DataFrame({"Room": nu.get_rooms(23,27,1)}).to_excel("new_may_output.xlsx", index=False)
